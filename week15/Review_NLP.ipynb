# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
imdb = keras.datasets.imdb
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=1000)

# %%
len(x_train), len(y_train)
# Out:
# (25000, 25000)

# %%
print(x_train[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 2, 2, 65, 458, 2, 66, 2, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 2, 2, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2, 19, 14, 22, 4, 2, 2, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 2, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2, 2, 16, 480, 66, 2, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 2, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 2, 15, 256, 4, 2, 7, 2, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 2, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2, 56, 26, 141, 6, 194, 2, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 2, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 2, 88, 12, 16, 283, 5, 16, 2, 113, 103, 32, 15, 16, 2, 19, 178, 32]

# %%
len(x_train[0]), len(x_train[1])
# Out:
# (218, 189)

# %%
y_train[0], y_train[1]
# Out:
# (np.int64(1), np.int64(0))

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1]), array([12500, 12500]))

# %%
from numpy._core.defchararray import index
word_to_index = imdb.get_word_index()

word_to_index = {k: (v+3) for k, v in word_to_index.items()}
word_to_index["<PAD>"] = 0
word_to_index["<START>"] = 1
word_to_index["<UNK>"] = 2
word_to_index["<UNUSED>"] = 3

index_to_word = dict([(value, key) for (key, value) in word_to_index.items()])

# %%
print(' '.join([index_to_word[index] for index in x_train[0]]))
# Out:
# <START> this film was just brilliant casting <UNK> <UNK> story direction <UNK> really <UNK> the part they played and you could just imagine being there robert <UNK> is an amazing actor and now the same being director <UNK> father came from the same <UNK> <UNK> as myself so i loved the fact there was a real <UNK> with this film the <UNK> <UNK> throughout the film were great it was just brilliant so much that i <UNK> the film as soon as it was released for <UNK> and would recommend it to everyone to watch and the <UNK> <UNK> was amazing really <UNK> at the end it was so sad and you know what they say if you <UNK> at a film it must have been good and this definitely was also <UNK> to the two little <UNK> that played the <UNK> of <UNK> and paul they were just brilliant children are often left out of the <UNK> <UNK> i think because the stars that play them all <UNK> up are such a big <UNK> for the whole film but these children are amazing and should be <UNK> for what they have done don't you think the whole story was so <UNK> because it was true and was <UNK> life after all that was <UNK> with us all

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import *

# %%
x_train = pad_sequences(x_train, maxlen=100)
x_test = pad_sequences(x_test, maxlen=100)

# %%
len(x_train[0]), len(x_train[1])
# Out:
# (100, 100)

# %%
print(x_train[0])
# Out:
# [  2  33   6  22  12 215  28  77  52   5  14 407  16  82   2   8   4 107
#  117   2  15 256   4   2   7   2   5 723  36  71  43 530 476  26 400 317
#   46   7   4   2   2  13 104  88   4 381  15 297  98  32   2  56  26 141
#    6 194   2  18   4 226  22  21 134 476  26 480   5 144  30   2  18  51
#   36  28 224  92  25 104   4 226  65  16  38   2  88  12  16 283   5  16
#    2 113 103  32  15  16   2  19 178  32]

# %%
vocab_size = 10000

model = Sequential()
model.add(Embedding(vocab_size, 64, input_length=100))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=64, epochs=20, verbose=1, validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7276 - loss: 0.5148 - val_accuracy: 0.8216 - val_loss: 0.3909
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8549 - loss: 0.3346 - val_accuracy: 0.8180 - val_loss: 0.3945
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.9097 - loss: 0.2270 - val_accuracy: 0.8036 - val_loss: 0.4780
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9563 - loss: 0.1212 - val_accuracy: 0.7966 - val_loss: 0.6028
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9814 - loss: 0.0590 - val_accuracy: 0.7917 - val_loss: 0.7834
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9912 - loss: 0.0308 - val_accuracy: 0.7864 - val_loss: 0.9366
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9956 - loss: 0.0175 - val_accuracy: 0.7906 - val_loss: 1.0751
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.9944 - loss: 0.0186 - val_accuracy: 0.7898 - val_loss: 1.1587
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.9929 - loss: 0.0215 - val_accuracy: 0.7796 - val_loss: 1.2425
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9942 - loss: 0.0176 - val_accuracy: 0.7840 - val_loss: 1.3096
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.9950 - loss: 0.0144 - val_accuracy: 0.7830 - val_loss: 1.3646
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9951 - loss: 0.0143 - val_accuracy: 0.7858 - val_loss: 1.4961
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9957 - loss: 0.0130 - val_accuracy: 0.7807 - val_loss: 1.5606
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9950 - loss: 0.0144 - val_accuracy: 0.7749 - val_loss: 1.5774
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9949 - loss: 0.0149 - val_accuracy: 0.7781 - val_loss: 1.6271
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.9960 - loss: 0.0122 - val_accuracy: 0.7784 - val_loss: 1.6977
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9970 - loss: 0.0089 - val_accuracy: 0.7780 - val_loss: 1.7543
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9966 - loss: 0.0098 - val_accuracy: 0.7686 - val_loss: 1.9511
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.9957 - loss: 0.0108 - val_accuracy: 0.7765 - val_loss: 1.8825
# Epoch 20/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9964 - loss: 0.0105 - val_accuracy: 0.7793 - val_loss: 1.9065

# %%
results = model.evaluate(x_test, y_test, verbose=2)
print(results)
# Out:
# 782/782 - 2s - 3ms/step - accuracy: 0.7793 - loss: 1.9065
# [1.9065171480178833, 0.7792800068855286]

# %%
review = "What can I say about this movie that was already said? It is my favorite time travel sci-fi, adventure epic comedy in the 80's and I love this movie to death! When I saw this movie I was thrown out by its theme. An excellent sci-fi, adventure epic, I LOVE the 80s. It's simple the greatest time travel movie ever happened in the history of world cinema. I love this movie to death, I love, LOVE, love it!"

# %%
import re
review = re.sub("[^0-9a-zA-Z ]", "", review).lower()

# %%
review_encoding = []

for w in review.split():
  index = word_to_index.get(w, 2)
  if index <= 10000:
    review_encoding.append(index)
  else:
    review_encoding.append(word_to_index["UNK"])

test_input = pad_sequences([review_encoding], maxlen=100)
value = model.predict(test_input)
if (value > 0.5):
  print("긍정적인 리뷰입니다.")
else:
  print("부정적인 리뷰입니다.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 긍정적인 리뷰입니다.
