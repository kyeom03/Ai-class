# %%
import pandas as pd
import numpy as np

path = '/content/drive/MyDrive/Colab Notebooks/abalone.csv'

df = pd.read_csv(path)

df
# Out:
#         id Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0        0   M   0.455     0.365   0.095        0.5140          0.2245
# 1        1   M   0.350     0.265   0.090        0.2255          0.0995
# 2        2   F   0.530     0.420   0.135        0.6770          0.2565
# 3        3   M   0.440     0.365   0.125        0.5160          0.2155
# 4        4   I   0.330     0.255   0.080        0.2050          0.0895
# ...    ...  ..     ...       ...     ...           ...             ...
# 4172  4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173  4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174  4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175  4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176  4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# id                0
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['Sex_encoded'] = le.fit_transform(df['Sex'])
df = df.drop(['id','Sex'], axis=1)

df.head()
# Out:
#    Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight  Rings  Sex_encoded
# 0         0.150     15            2
# 1         0.070      7            2
# 2         0.210      9            0
# 3         0.155     10            2
# 4         0.055      7            1

# %%
y=df['Rings']
y.value_counts()
# Out:
# Rings
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 24      2
# 27      2
# 1       1
# 29      1
# 26      1
# 2       1
# 25      1
# Name: count, dtype: int64

# %%
def classify_age(r):
    if r <= 7:
        return 0   # young
    elif r <= 11:
        return 1   # middle
    else:
        return 2   # old

y = df['Rings'].apply(classify_age)
y.value_counts()
# Out:
# Rings
# 1    2378
# 2     960
# 0     839
# Name: count, dtype: int64

# %%
X=df.drop('Rings',axis=1)
X.head()
# Out:
#    Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight  Sex_encoded
# 0         0.150            2
# 1         0.070            2
# 2         0.210            0
# 3         0.155            2
# 4         0.055            1

# %%
Y = pd.get_dummies(y).values
X = X.values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
#Standardization
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
#Defining the model

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam

model = Sequential()

model.add(Dense(10,input_shape=(X.shape[1],),activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(y_train.shape[1],activation='softmax'))

model.compile(Adam(learning_rate=0.001),'categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 10)             │            90 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 8)              │            88 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 6)              │            54 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 3)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 253 (1012.00 B)
#  Trainable params: 253 (1012.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model_history = model.fit(x=X_train, y=y_train, epochs=30, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6513 - loss: 0.9257 - val_accuracy: 0.6567 - val_loss: 0.8576
# Epoch 2/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6761 - loss: 0.7962 - val_accuracy: 0.6579 - val_loss: 0.7527
# Epoch 3/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6869 - loss: 0.6933 - val_accuracy: 0.6962 - val_loss: 0.6946
# Epoch 4/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7121 - loss: 0.6543 - val_accuracy: 0.7033 - val_loss: 0.6804
# Epoch 5/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7145 - loss: 0.6377 - val_accuracy: 0.7189 - val_loss: 0.6667
# Epoch 6/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7246 - loss: 0.6282 - val_accuracy: 0.7189 - val_loss: 0.6605
# Epoch 7/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7270 - loss: 0.6197 - val_accuracy: 0.7129 - val_loss: 0.6659
# Epoch 8/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7297 - loss: 0.6144 - val_accuracy: 0.7237 - val_loss: 0.6465
# Epoch 9/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7285 - loss: 0.6080 - val_accuracy: 0.7261 - val_loss: 0.6394
# Epoch 10/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7351 - loss: 0.6043 - val_accuracy: 0.7285 - val_loss: 0.6421
# Epoch 11/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7384 - loss: 0.6014 - val_accuracy: 0.7309 - val_loss: 0.6301
# Epoch 12/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7393 - loss: 0.5981 - val_accuracy: 0.7344 - val_loss: 0.6269
# Epoch 13/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7357 - loss: 0.5947 - val_accuracy: 0.7261 - val_loss: 0.6251
# Epoch 14/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7438 - loss: 0.5924 - val_accuracy: 0.7344 - val_loss: 0.6175
# Epoch 15/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7375 - loss: 0.5917 - val_accuracy: 0.7309 - val_loss: 0.6115
# Epoch 16/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7414 - loss: 0.5895 - val_accuracy: 0.7356 - val_loss: 0.6095
# Epoch 17/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7420 - loss: 0.5879 - val_accuracy: 0.7392 - val_loss: 0.6106
# Epoch 18/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7456 - loss: 0.5865 - val_accuracy: 0.7344 - val_loss: 0.6046
# Epoch 19/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7486 - loss: 0.5843 - val_accuracy: 0.7333 - val_loss: 0.6037
# Epoch 20/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7429 - loss: 0.5853 - val_accuracy: 0.7333 - val_loss: 0.5998
# Epoch 21/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7441 - loss: 0.5836 - val_accuracy: 0.7333 - val_loss: 0.6025
# Epoch 22/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7486 - loss: 0.5831 - val_accuracy: 0.7309 - val_loss: 0.6002
# Epoch 23/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7465 - loss: 0.5817 - val_accuracy: 0.7285 - val_loss: 0.6119
# Epoch 24/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7522 - loss: 0.5805 - val_accuracy: 0.7321 - val_loss: 0.5957
# Epoch 25/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7480 - loss: 0.5802 - val_accuracy: 0.7344 - val_loss: 0.5946
# Epoch 26/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7450 - loss: 0.5802 - val_accuracy: 0.7368 - val_loss: 0.5948
# Epoch 27/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7498 - loss: 0.5806 - val_accuracy: 0.7344 - val_loss: 0.5932
# Epoch 28/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7480 - loss: 0.5805 - val_accuracy: 0.7333 - val_loss: 0.5932
# Epoch 29/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7486 - loss: 0.5790 - val_accuracy: 0.7333 - val_loss: 0.5942
# Epoch 30/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7474 - loss: 0.5777 - val_accuracy: 0.7368 - val_loss: 0.5918
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = model_history.history['accuracy']
val_acc = model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.72      0.77       194
#            1       0.71      0.85      0.77       442
#            2       0.74      0.49      0.59       200
#
#     accuracy                           0.74       836
#    macro avg       0.76      0.69      0.71       836
# weighted avg       0.74      0.74      0.73       836
#
# [[140  54   0]
#  [ 31 377  34]
#  [  0 101  99]]
