# %%
import pandas as pd
import numpy as np

path = '/content/drive/MyDrive/Colab Notebooks/breast_cancer.csv'

df = pd.read_csv(path)

df
# Out:
#      Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0             0        17.99         10.38          122.80     1001.0
# 1             1        20.57         17.77          132.90     1326.0
# 2             2        19.69         21.25          130.00     1203.0
# 3             3        11.42         20.38           77.58      386.1
# 4             4        20.29         14.34          135.10     1297.0
# ..          ...          ...           ...             ...        ...
# 564         564        21.56         22.39          142.00     1479.0
# 565         565        20.13         28.25          131.20     1261.0
# 566         566        16.60         28.08          108.30      858.1
# 567         567        20.60         29.33          140.10     1265.0
# 568         568         7.76         24.54           47.92      181.0
#
#      mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      mean symmetry  ...  worst texture  worst perimeter  worst area  \
# 0           0.2419  ...          17.33           184.60      2019.0
# 1           0.1812  ...          23.41           158.80      1956.0
# 2           0.2069  ...          25.53           152.50      1709.0
# 3           0.2597  ...          26.50            98.87       567.7
# 4           0.1809  ...          16.67           152.20      1575.0
# ..             ...  ...            ...              ...         ...
# 564         0.1726  ...          26.40           166.10      2027.0
# 565         0.1752  ...          38.25           155.00      1731.0
# 566         0.1590  ...          34.12           126.70      1124.0
# 567         0.2397  ...          39.42           184.60      1821.0
# 568         0.1587  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  label
# 0                  0.2654          0.4601                  0.11890      0
# 1                  0.1860          0.2750                  0.08902      0
# 2                  0.2430          0.3613                  0.08758      0
# 3                  0.2575          0.6638                  0.17300      0
# 4                  0.1625          0.2364                  0.07678      0
# ..                    ...             ...                      ...    ...
# 564                0.2216          0.2060                  0.07115      0
# 565                0.1628          0.2572                  0.06637      0
# 566                0.1418          0.2218                  0.07820      0
# 567                0.2650          0.4087                  0.12400      0
# 568                0.0000          0.2871                  0.07039      1
#
# [569 rows x 32 columns]

# %%
df2=df.drop('label',axis=1)
df2.head()
# Out:
#    Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0           0        17.99         10.38          122.80     1001.0
# 1           1        20.57         17.77          132.90     1326.0
# 2           2        19.69         21.25          130.00     1203.0
# 3           3        11.42         20.38           77.58      386.1
# 4           4        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    mean symmetry  ...  worst radius  worst texture  worst perimeter  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
y=df2['worst compactness']
y.value_counts()
# Out:
# worst compactness
# 0.3416    3
# 0.1486    3
# 0.3055    2
# 0.1963    2
# 0.2264    2
#          ..
# 0.3299    1
# 0.1610    1
# 0.3547    1
# 0.7584    1
# 0.4056    1
# Name: count, Length: 529, dtype: int64

# %%
X=df2.drop('worst compactness',axis=1)
X.head()
# Out:
#    Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0           0        17.99         10.38          122.80     1001.0
# 1           1        20.57         17.77          132.90     1326.0
# 2           2        19.69         21.25          130.00     1203.0
# 3           3        11.42         20.38           77.58      386.1
# 4           4        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    mean symmetry  ...  fractal dimension error  worst radius  worst texture  \
# 0         0.2419  ...                 0.006193         25.38          17.33
# 1         0.1812  ...                 0.003532         24.99          23.41
# 2         0.2069  ...                 0.004571         23.57          25.53
# 3         0.2597  ...                 0.009208         14.91          26.50
# 4         0.1809  ...                 0.005115         22.54          16.67
#
#    worst perimeter  worst area  worst smoothness  worst concavity  \
# 0           184.60      2019.0            0.1622           0.7119
# 1           158.80      1956.0            0.1238           0.2416
# 2           152.50      1709.0            0.1444           0.4504
# 3            98.87       567.7            0.2098           0.6869
# 4           152.20      1575.0            0.1374           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
Y = y.values
X = X.values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
#Standardization
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

y_scaler = StandardScaler()
y_train = y_scaler.fit_transform(y_train.reshape(-1,1))
y_test = y_scaler.transform(y_test.reshape(-1,1))

# %%
#Defining the model

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam

model = Sequential()

model.add(Dense(8,input_shape=(X.shape[1],),activation='relu'))
model.add(Dense(30,activation='relu'))
model.add(Dense(30,activation='relu'))
model.add(Dense(1))

model.compile(optimizer = 'adam', loss = 'mse', metrics = ['mse'])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │           248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 30)             │           270 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 30)             │           930 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,479 (5.78 KB)
#  Trainable params: 1,479 (5.78 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_history = model.fit(x=X_train, y=y_train, epochs=30, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)
# Out:
# Epoch 1/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: 0.8963 - mse: 0.8963 - val_loss: 0.9591 - val_mse: 0.9591
# Epoch 2/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6390 - mse: 0.6390 - val_loss: 0.6528 - val_mse: 0.6528
# Epoch 3/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4502 - mse: 0.4502 - val_loss: 0.4345 - val_mse: 0.4345
# Epoch 4/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3254 - mse: 0.3254 - val_loss: 0.3277 - val_mse: 0.3277
# Epoch 5/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2544 - mse: 0.2544 - val_loss: 0.2533 - val_mse: 0.2533
# Epoch 6/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2029 - mse: 0.2029 - val_loss: 0.2035 - val_mse: 0.2035
# Epoch 7/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1656 - mse: 0.1656 - val_loss: 0.1731 - val_mse: 0.1731
# Epoch 8/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1389 - mse: 0.1389 - val_loss: 0.1458 - val_mse: 0.1458
# Epoch 9/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1245 - mse: 0.1245 - val_loss: 0.1380 - val_mse: 0.1380
# Epoch 10/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1123 - mse: 0.1123 - val_loss: 0.1301 - val_mse: 0.1301
# Epoch 11/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1033 - mse: 0.1033 - val_loss: 0.1224 - val_mse: 0.1224
# Epoch 12/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0954 - mse: 0.0954 - val_loss: 0.1318 - val_mse: 0.1318
# Epoch 13/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0952 - mse: 0.0952 - val_loss: 0.1181 - val_mse: 0.1181
# Epoch 14/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0886 - mse: 0.0886 - val_loss: 0.1103 - val_mse: 0.1103
# Epoch 15/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0822 - mse: 0.0822 - val_loss: 0.1098 - val_mse: 0.1098
# Epoch 16/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0776 - mse: 0.0776 - val_loss: 0.1064 - val_mse: 0.1064
# Epoch 17/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0715 - mse: 0.0715 - val_loss: 0.1102 - val_mse: 0.1102
# Epoch 18/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0698 - mse: 0.0698 - val_loss: 0.1081 - val_mse: 0.1081
# Epoch 19/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0664 - mse: 0.0664 - val_loss: 0.1003 - val_mse: 0.1003
# Epoch 20/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0672 - mse: 0.0672 - val_loss: 0.0979 - val_mse: 0.0979
# Epoch 21/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0637 - mse: 0.0637 - val_loss: 0.1264 - val_mse: 0.1264
# Epoch 22/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0695 - mse: 0.0695 - val_loss: 0.0956 - val_mse: 0.0956
# Epoch 23/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0597 - mse: 0.0597 - val_loss: 0.0912 - val_mse: 0.0912
# Epoch 24/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0559 - mse: 0.0559 - val_loss: 0.0908 - val_mse: 0.0908
# Epoch 25/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0538 - mse: 0.0538 - val_loss: 0.0895 - val_mse: 0.0895
# Epoch 26/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0522 - mse: 0.0522 - val_loss: 0.0889 - val_mse: 0.0889
# Epoch 27/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0516 - mse: 0.0516 - val_loss: 0.0886 - val_mse: 0.0886
# Epoch 28/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0503 - mse: 0.0503 - val_loss: 0.0888 - val_mse: 0.0888
# Epoch 29/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0838 - val_mse: 0.0838
# Epoch 30/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0471 - mse: 0.0471 - val_loss: 0.0823 - val_mse: 0.0823
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
#y값 스케일링 복원
y_pred = y_scaler.inverse_transform(y_pred)
y_test_original = y_scaler.inverse_transform(y_test)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#MSE,MAE,R2 of the predicted values
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

print("MSE:", mean_squared_error(y_test_original, y_pred))
print("MAE:", mean_absolute_error(y_test_original, y_pred))
print("R2:", r2_score(y_test_original, y_pred))
# Out:
# MSE: 0.00192482935364185
# MAE: 0.030648635762077672
# R2: 0.9355508682428361

# %%
model.evaluate(X_test, y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0823 - mse: 0.0823
# [0.08228947222232819, 0.08228947222232819]
