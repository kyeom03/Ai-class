# %%
import pandas as pd
import numpy as np

path = '/content/drive/MyDrive/Colab Notebooks/breast_cancer.csv'

df = pd.read_csv(path)

df
# Out:
#      Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0             0        17.99         10.38          122.80     1001.0
# 1             1        20.57         17.77          132.90     1326.0
# 2             2        19.69         21.25          130.00     1203.0
# 3             3        11.42         20.38           77.58      386.1
# 4             4        20.29         14.34          135.10     1297.0
# ..          ...          ...           ...             ...        ...
# 564         564        21.56         22.39          142.00     1479.0
# 565         565        20.13         28.25          131.20     1261.0
# 566         566        16.60         28.08          108.30      858.1
# 567         567        20.60         29.33          140.10     1265.0
# 568         568         7.76         24.54           47.92      181.0
#
#      mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      mean symmetry  ...  worst texture  worst perimeter  worst area  \
# 0           0.2419  ...          17.33           184.60      2019.0
# 1           0.1812  ...          23.41           158.80      1956.0
# 2           0.2069  ...          25.53           152.50      1709.0
# 3           0.2597  ...          26.50            98.87       567.7
# 4           0.1809  ...          16.67           152.20      1575.0
# ..             ...  ...            ...              ...         ...
# 564         0.1726  ...          26.40           166.10      2027.0
# 565         0.1752  ...          38.25           155.00      1731.0
# 566         0.1590  ...          34.12           126.70      1124.0
# 567         0.2397  ...          39.42           184.60      1821.0
# 568         0.1587  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  label
# 0                  0.2654          0.4601                  0.11890      0
# 1                  0.1860          0.2750                  0.08902      0
# 2                  0.2430          0.3613                  0.08758      0
# 3                  0.2575          0.6638                  0.17300      0
# 4                  0.1625          0.2364                  0.07678      0
# ..                    ...             ...                      ...    ...
# 564                0.2216          0.2060                  0.07115      0
# 565                0.1628          0.2572                  0.06637      0
# 566                0.1418          0.2218                  0.07820      0
# 567                0.2650          0.4087                  0.12400      0
# 568                0.0000          0.2871                  0.07039      1
#
# [569 rows x 32 columns]

# %%
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  label
# 0                  0.2654          0.4601                  0.11890      0
# 1                  0.1860          0.2750                  0.08902      0
# 2                  0.2430          0.3613                  0.08758      0
# 3                  0.2575          0.6638                  0.17300      0
# 4                  0.1625          0.2364                  0.07678      0
# ..                    ...             ...                      ...    ...
# 564                0.2216          0.2060                  0.07115      0
# 565                0.1628          0.2572                  0.06637      0
# 566                0.1418          0.2218                  0.07820      0
# 567                0.2650          0.4087                  0.12400      0
# 568                0.0000          0.2871                  0.07039      1
#
# [569 rows x 31 columns]

# %%
df2=df.drop('label',axis=1)
df2.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
y=df2['worst compactness']
y.value_counts()
# Out:
# worst compactness
# 0.3416    3
# 0.1486    3
# 0.3055    2
# 0.1963    2
# 0.2264    2
#          ..
# 0.3299    1
# 0.1610    1
# 0.3547    1
# 0.7584    1
# 0.4056    1
# Name: count, Length: 529, dtype: int64

# %%
X=df2.drop('worst compactness',axis=1)
X.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  fractal dimension error  worst radius  \
# 0                 0.07871  ...                 0.006193         25.38
# 1                 0.05667  ...                 0.003532         24.99
# 2                 0.05999  ...                 0.004571         23.57
# 3                 0.09744  ...                 0.009208         14.91
# 4                 0.05883  ...                 0.005115         22.54
#
#    worst texture  worst perimeter  worst area  worst smoothness  \
# 0          17.33           184.60      2019.0            0.1622
# 1          23.41           158.80      1956.0            0.1238
# 2          25.53           152.50      1709.0            0.1444
# 3          26.50            98.87       567.7            0.2098
# 4          16.67           152.20      1575.0            0.1374
#
#    worst concavity  worst concave points  worst symmetry  \
# 0           0.7119                0.2654          0.4601
# 1           0.2416                0.1860          0.2750
# 2           0.4504                0.2430          0.3613
# 3           0.6869                0.2575          0.6638
# 4           0.4000                0.1625          0.2364
#
#    worst fractal dimension
# 0                  0.11890
# 1                  0.08902
# 2                  0.08758
# 3                  0.17300
# 4                  0.07678
#
# [5 rows x 29 columns]

# %%
Y = y.values
X = X.values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
#Standardization
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

y_scaler = StandardScaler()
y_train = y_scaler.fit_transform(y_train.reshape(-1,1))
y_test = y_scaler.transform(y_test.reshape(-1,1))

# %%
#Defining the model

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam

model = Sequential()

model.add(Dense(8,input_shape=(X.shape[1],),activation='relu'))
model.add(Dense(30,activation='relu'))
model.add(Dense(30,activation='relu'))
model.add(Dense(1))

model.compile(optimizer = 'adam', loss = 'mse', metrics = ['mse'])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 30)             │           270 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 30)             │           930 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,471 (5.75 KB)
#  Trainable params: 1,471 (5.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_history = model.fit(x=X_train, y=y_train, epochs=30, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)
# Out:
# Epoch 1/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6644 - mse: 0.6644 - val_loss: 0.7711 - val_mse: 0.7711
# Epoch 2/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3939 - mse: 0.3939 - val_loss: 0.5426 - val_mse: 0.5426
# Epoch 3/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2567 - mse: 0.2567 - val_loss: 0.4213 - val_mse: 0.4213
# Epoch 4/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2087 - mse: 0.2087 - val_loss: 0.3486 - val_mse: 0.3486
# Epoch 5/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1851 - mse: 0.1851 - val_loss: 0.2981 - val_mse: 0.2981
# Epoch 6/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1666 - mse: 0.1666 - val_loss: 0.2632 - val_mse: 0.2632
# Epoch 7/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1531 - mse: 0.1531 - val_loss: 0.2461 - val_mse: 0.2461
# Epoch 8/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1378 - mse: 0.1378 - val_loss: 0.2199 - val_mse: 0.2199
# Epoch 9/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1274 - mse: 0.1274 - val_loss: 0.2060 - val_mse: 0.2060
# Epoch 10/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1188 - mse: 0.1188 - val_loss: 0.1864 - val_mse: 0.1864
# Epoch 11/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1098 - mse: 0.1098 - val_loss: 0.1755 - val_mse: 0.1755
# Epoch 12/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1057 - mse: 0.1057 - val_loss: 0.1629 - val_mse: 0.1629
# Epoch 13/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0985 - mse: 0.0985 - val_loss: 0.1552 - val_mse: 0.1552
# Epoch 14/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1029 - mse: 0.1029 - val_loss: 0.1523 - val_mse: 0.1523
# Epoch 15/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0911 - mse: 0.0911 - val_loss: 0.1473 - val_mse: 0.1473
# Epoch 16/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0853 - mse: 0.0853 - val_loss: 0.1411 - val_mse: 0.1411
# Epoch 17/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0800 - mse: 0.0800 - val_loss: 0.1380 - val_mse: 0.1380
# Epoch 18/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0776 - mse: 0.0776 - val_loss: 0.1327 - val_mse: 0.1327
# Epoch 19/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0740 - mse: 0.0740 - val_loss: 0.1317 - val_mse: 0.1317
# Epoch 20/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0735 - mse: 0.0735 - val_loss: 0.1236 - val_mse: 0.1236
# Epoch 21/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0695 - mse: 0.0695 - val_loss: 0.1220 - val_mse: 0.1220
# Epoch 22/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0692 - mse: 0.0692 - val_loss: 0.1176 - val_mse: 0.1176
# Epoch 23/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0643 - mse: 0.0643 - val_loss: 0.1182 - val_mse: 0.1182
# Epoch 24/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0630 - mse: 0.0630 - val_loss: 0.1121 - val_mse: 0.1121
# Epoch 25/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0609 - mse: 0.0609 - val_loss: 0.1100 - val_mse: 0.1100
# Epoch 26/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0593 - mse: 0.0593 - val_loss: 0.1086 - val_mse: 0.1086
# Epoch 27/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0565 - mse: 0.0565 - val_loss: 0.1057 - val_mse: 0.1057
# Epoch 28/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0551 - mse: 0.0551 - val_loss: 0.1045 - val_mse: 0.1045
# Epoch 29/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0547 - mse: 0.0547 - val_loss: 0.1028 - val_mse: 0.1028
# Epoch 30/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0531 - mse: 0.0531 - val_loss: 0.1000 - val_mse: 0.1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
#y값 스케일링 복원
y_pred = y_scaler.inverse_transform(y_pred)
y_test_original = y_scaler.inverse_transform(y_test)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#MSE,MAE,R2 of the predicted values
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

print("MSE:", mean_squared_error(y_test_original, y_pred))
print("MAE:", mean_absolute_error(y_test_original, y_pred))
print("R2:", r2_score(y_test_original, y_pred))
# Out:
# MSE: 0.002338681884000445
# MAE: 0.036236006236290724
# R2: 0.921693828808846

# %%
model.evaluate(X_test, y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1000 - mse: 0.1000
# [0.09998231381177902, 0.09998231381177902]
